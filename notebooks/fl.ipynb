# %%
import pandas as pd
from os import listdir
import numpy as np
import re
from collections import Counter

search = 'exel'

mypath = '../fl/source/'
keywords = []

for f in listdir(mypath):
    file = open(mypath + f,'r', encoding='utf-8')
    headers = file.read().split('\n')
    for h in headers:
        if len(re.findall(search, h)) > 0:
            print(h)
            keywords.extend(h.split())
    file.close()

c = Counter(keywords)
x = pd.DataFrame({'tag': c.keys(), 'val': c.values()})
x.sort_values('val', inplace=True, ascending=False)
#x.to_csv(search + '.csv', encoding='utf-8', sep=',', index=False)
# Out:
# заполнение шаблона exel ( ozon ) наконечник рулевой
# заполнение шаблона exel ( ozon ) очистители автомобильные
# заполнение шаблона exel ( ozon ) лампы автомобильные
# заполнение шаблона exel ( ozon ) авто масла
# заполнение шаблона exel ( ozon ) фильтр топливный для авто
# заполнение шаблона exel ( ozon ) фильтр маслянный для авто
# заполнение шаблона exel ( ozon ) фильтр воздушный для авто
# заполнение шаблона exel ( ozon ) стартеры для авто
# заполнение шаблона exel ( ozon ) авто смазка
# заполнение шаблона exel ( ozon ) очки водительские
# заполнение шаблона exel ( ozon ) авто масла idimitsu
# заполнение шаблона exel ( ozon ) авто масла газпромнефть
# заполнение шаблона exel ( ozon ) авто масла elf и ford
# заполнение шаблона exel ( ozon ) авто масла castrol
# заполнение шаблона exel ( ozon ) катушка зажигания
# восстановить таблицу exel
# заполнение шаблона exel ( ozon ) подшипник ступичный
# заполнение шаблона exel ( ozon ) крестовина карданного вала
# заполнение шаблона exel ( ozon ) колодки тормозные
# заполнение шаблона exel ( ozon ) диск тормозной
# заполнение шаблона exel ( ozon ) амортизаторы (101-200) 100 товаров
# заполнение шаблона exel ( ozon ) антифриз
# создание единой базы данных из подгружаемой каждую неделю таблицы еженедельного отчета в exel «де
# сделать простой парсер данных из html таблицы в google datasheets (exel)
# интеграция exel и crm
# макрос exel vba
# выгрузка базы mysql в exel на php
# автоматизация телеграмм exel
# работа с exel файлом (распределение характеристик для товаров)
# парсер xml в exel
# перенести макрос exel в google таблицы
# заполнение шаблона exel ( ozon ) наконечник рулевой
# восстановить таблицу exel
# обработка статистических данных в психологии, математическая обработка, exel, spss
# обработка статистических данных в психологии, математическая обработка, exel, spss
# создать таблицу exel для учета рекламных затрат
# переименовать фотографии и вставить названия фоток в exel файл согласно шаблону
# разобраться в структуре exel таблицы, подробно расписать принцип её работы.
# разработка макроса для exel (office 365)
# калькулятор  в exel
# агрегация данных из множества таблиц exel
# работа с exel файлом (распределение характеристик для товаров)
# парсер xml в exel
# заполнение шаблона exel ( ozon ) наконечник рулевой
# восстановить таблицу exel
# сделать удобную exel таблицу спецификации
# изменить локально сметный расчет предоставленный в формате exel. сделать на основании лср кс2 и кс3
# перенести данные из exell в word и добавить фото, 600 позиций
# переименовать фотографии и вставить названия фоток в exel файл согласно шаблону
# оформить структуру предприятия в exel
# создать бланки коммерческого предложения в exel
# показать рабочий способ преобразовать xml файл в exel или csv
# простой график по данным из exel
# изменить локально сметный расчет предоставленный в формате exel. сделать на основании лср кс2 и кс3
# перенести данные из exell в word и добавить фото, 600 позиций
# формула для exel
# создание актов выполненных работ в word ,заполняемых данными из exel
# google adwords ads exel экспорта > ексель импорта xls
# настроить exel таблицы для учёта
# создать табличку в exel
# доработка exel таблицы для первичного дневного фин отчета в гугл таблицах
# создание актов выполненных работ в word ,заполняемых данными из exel
# google adwords ads exel экспорта > ексель импорта xls
# макрос в exel
# перенести таблицу с сайта в exel
# печать этикеток из exel (утилита)
# автоматизированный таймлайн в google таблицы или exel
# доработка exel таблицы для первичного дневного фин отчета в гугл таблицах
# для расчета расхода изделий потолочных систем разработать калькулятор в exel
# парсинг данных по наименованию организации и фио. готовый результат  таблица в формате exel
# найти телефоны контактного лица по базе данных, занести в таблицу exel для загрузки в битрикс
# помощь в составлении нескольких гистаграмм в exel для презентации
# агрегация данных из множества таблиц exel
# задание по предмету матстатистика в exel
# программа на python которая собирает данные из exel онлайн
# перенести таблицу с сайта в exel
# печать этикеток из exel (утилита)
# автоматизированный таймлайн в google таблицы или exel
# перенос с pdf в word и exel ( без ошибок как есть в оригинале)
# работа в openoffice calc (exel на минималках)
# помощь в составлении нескольких гистаграмм в exel для презентации
# агрегация данных из множества таблиц exel
# задание по предмету матстатистика в exel
# программа на python которая собирает данные из exel онлайн
# простое приложение на c# , поиск в окне приложения данных в exel файле
# заполнить прайс в exel
# выделение ячеек цветом в exel при определенных параметрах
# помочь с exel. работа с формулой впр/ аналогом. нужно помочь с обновлением прайса магазина и постав.
# решить задания в exel (формулы, диаграммы)
# создать скрипт для перевода данных из таблицы exel в таблицу word по заданному алгоритму
# дизайн готовый exel таблиицы
# перенос с pdf в word и exel ( без ошибок как есть в оригинале)
# работа в openoffice calc (exel на минималках)
# составить и в последующем внести коррективы в exel, google таблицы
# оформить референс из таблицы exel в приглядный вид
# создать скрипт для перевода данных из таблицы exel в таблицу word по заданному алгоритму
# дизайн готовый exel таблиицы
# скринер с выгрузкой в exel таблицу
# необходимо сформировать выгрузку из 1с fresh в exel
# конвертация файла с расширением gdb (возможно interbase старая) в таблицы exell.
# оформить референс из таблицы exel в приглядный вид
# написать формулу в exel используя стандотклон и срзнач по заранее заданой формуле
# скринер с выгрузкой в exel таблицу
# конвертация файла с расширением gdb (возможно interbase старая) в таблицы exell.
# перенос текста из файла exel в графический редактор согласно макету
# конвертер файлов exel (из одного шаблонного файла сделать другой)
# парсинг товара (цена, фото(прямая ссылка на фото), артикул, описание, все залить в exel таблицу)
# заполнить поле email в exel табличке, 1500 строк
# конвертер файлов exel (из одного шаблонного файла сделать другой)
# заполнение технических характеристик товаров в таблице exel
# парсинг товара (цена, фото(прямая ссылка на фото), артикул, описание, все залить в exel таблицу)
# заполнить поле email в exel табличке, 1500 строк
# скрипт для exel, который из колонки с ячейками, содержащими url сайта будет извлекать адрес компании
# сделать таблицу exel
# программа для внесения актуальных цен в наш прайс exel из прайсов exel поставщиков.
# парсинг данных с сайта и запись данных в exel
# составить и в последующем внести коррективы в exel, google таблицы
# парсинг товара (цена, фото(прямая ссылка на фото), артикул, описание, все залить в exel таблицу)
# макрос в exel для преобразование шрифта gost type a в другой поддерживающий кирилицу.
# exel связанные таблицы
# скрипт для exel, который из колонки с ячейками, содержащими url сайта будет извлекать адрес компании
# программа для внесения актуальных цен в наш прайс exel из прайсов exel поставщиков.
# парсинг данных с сайта и запись данных в exel
# составить и в последующем внести коррективы в exel, google таблицы
# создать формулу в exel
# создать макрос/плагин для exel  занесение штрихкодов в таблицу, сохранение и передача данных
# не сложная работа со сводной таблицей в exel
# exel подкорректировать шаблон договора
# сайт с автозаполнением word и exel файлов
# форматирование в exel
# помощник со знанием exel
# создать формулу в exel
# создать макрос/плагин для exel  занесение штрихкодов в таблицу, сохранение и передача данных
# не сложная работа со сводной таблицей в exel
# перенести расчетные значения из exel в формулы word
# загрузить отчет комиссионера озон, вб из exel или api в 1с
# дисциплина "системный анализ" в  exel
# решение заданий базового уровня в microsoft ofice (word, exel, power point)
# работа с текстом в exel
# задания в microsoft acces, word, exel
# дисциплина "системный анализ" в  exel
# перенести данные со скриншотов в exel
# telegram bot > exel
# работа в exel, внесение данных (плюс парсинг данных в таблицу)
# работа с текстом в exel
# задания в microsoft acces, word, exel
# знаток exel
# разработка шаблона для автоматического заполнения позиций из таблицы exel в текст word
# работа в exel, внесение данных (плюс парсинг данных в таблицу)
# прайс лист в таблице exel
# таблица с переменными данными exel
# разработка шаблона для автоматического заполнения позиций из таблицы exel в текст word
# ручное заполнение базы контактов в exel
# нужно сделать макрос для таблиц exel
# сделать exel макрос для выборки с разных листов одного документа по определенному полю
# загрузка из файла exel  в sql
# работа с данными в exel , лабораторная работа
# таблица exel для обменника криптовалют
# массовое создание pdf из exel
# нужно сделать макрос для таблиц exel
# сделать exel макрос для выборки с разных листов одного документа по определенному полю
# необходимо сделать красивую таблицу exel
# перевести ведомость отделочных работ из pdf в exel
# массовое создание pdf из exel
# сделать коммерческую смету в exel
# перенос сметы из pdf в exel
# отчет в exel
# необходимо сделать красивую таблицу exel
#  выполнить задания в exel
# требуется выполнить задание по exel для университета
# нужно выполнить задание по exel для университета
# сравнить данные из exel таблиц и выделить несоответствия.
# отчет в exel
# сравнить данные из exel таблиц и выделить несоответствия.
# собрать данные в exel табличку
# распределить наименования характеристик по видам товаров в файле exel
# составление заявок для торговых процедур по предоставленной документации (word, exel)
# exel visual basic
# сформировать exel таблицу на основе данных из каталога
# создать плагин для автоматической передачи данных из exel в figma
# сделать xml фид для яндекс директ из exel файла товаров
# разобрать файл pdf, собрать данные в таблицу exell.
# сделать спецификацию в exel из pdf дизайн-проекта
# переделать таблицу из exel в google
