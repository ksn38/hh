# %%
import pandas as pd
import numpy as np
from os import listdir
from os.path import isfile, join

# %%
mypath = 'C:\\Users\\DFNO\\fin\\hh'
files = [f for f in listdir(mypath) if isfile(join(mypath, f))]
print(files)
# Out:
# ['4.csv', 'cpp151120.csv', 'cppres151120.csv', 'dj040121.csv', 'ds040121.csv', 'ds151120.csv', 'dsres040121.csv', 'dsres151120.csv', 'java040121.csv', 'javares040121.csv', 'javares151120.csv', 'js040121.csv', 'js151120.csv', 'jsres040121.csv', 'jsres151120.csv', 'php040121.csv', 'php151120.csv', 'phpres040121.csv', 'phpres151120.csv', 'py040121.csv', 'py151120.csv', 'pyres040121.csv', 'pyres151120.csv', 'scala040121.csv', 'scala151120.csv', 'scalares151120.csv', 'Untitled.ipynb']

# %%
df = pd.read_csv('py040121.csv')
df.head(50)
# Out:
#                                      tag  count
# 0                                 Python    806
# 1                       Django Framework    328
# 2                             PostgreSQL    305
# 3                                    Git    305
# 4                                  Linux    262
# 5                                    SQL    255
# 6                                  MySQL    103
# 7                             JavaScript     97
# 8                                  Redis     83
# 9                        Английский язык     78
# 10                                 Flask     78
# 11                               MongoDB     74
# 12                                Docker     66
# 13                                   ООП     59
# 14             Английский — B1 — Средний     55
# 15  Английский — B2 — Средне-продвинутый     53
# 16                                   C++     50
# 17                                  REST     41
# 18                                   CSS     38
# ...
